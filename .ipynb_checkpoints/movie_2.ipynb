# %%
import numpy as np 
import pandas as pd

# %%
credits=pd.read_csv('credits.csv')

# %%
credits
# Out:
#                                                     cast  \
# 0      [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1      [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2      [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3      [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4      [{'cast_id': 1, 'character': 'George Banks', '...
# ...                                                  ...
# 45471  [{'cast_id': 0, 'character': '', 'credit_id': ...
# 45472  [{'cast_id': 1002, 'character': 'Sister Angela...
# 45473  [{'cast_id': 6, 'character': 'Emily Shaw', 'cr...
# 45474  [{'cast_id': 2, 'character': '', 'credit_id': ...
# 45475                                                 []
#
#                                                     crew      id
# 0      [{'credit_id': '52fe4284c3a36847f8024f49', 'de...     862
# 1      [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...    8844
# 2      [{'credit_id': '52fe466a9251416c75077a89', 'de...   15602
# 3      [{'credit_id': '52fe44779251416c91011acb', 'de...   31357
# 4      [{'credit_id': '52fe44959251416c75039ed7', 'de...   11862
# ...                                                  ...     ...
# 45471  [{'credit_id': '5894a97d925141426c00818c', 'de...  439050
# 45472  [{'credit_id': '52fe4af1c3a36847f81e9b15', 'de...  111109
# 45473  [{'credit_id': '52fe4776c3a368484e0c8387', 'de...   67758
# 45474  [{'credit_id': '533bccebc3a36844cf0011a7', 'de...  227506
# 45475  [{'credit_id': '593e676c92514105b702e68e', 'de...  461257
#
# [45476 rows x 3 columns]

# %%
credits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45476 entries, 0 to 45475
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   cast    45476 non-null  object
#  1   crew    45476 non-null  object
#  2   id      45476 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 1.0+ MB

# %%
credits.columns
# Out:
# Index(['cast', 'crew', 'id'], dtype='object')

# %%
meta =pd.read_csv('movies_metadata.csv')
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
meta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
#  14  release_date           45379 non-null  object
#  15  revenue                45460 non-null  float64
#  16  runtime                45203 non-null  float64
#  17  spoken_languages       45460 non-null  object
#  18  status                 45379 non-null  object
#  19  tagline                20412 non-null  object
#  20  title                  45460 non-null  object
#  21  video                  45460 non-null  object
#  22  vote_average           45460 non-null  float64
#  23  vote_count             45460 non-null  float64
# dtypes: float64(4), object(20)
# memory usage: 8.3+ MB

# %%
meta['release_date']=pd.to_datetime(meta['release_date'],errors='coerce')

# %%
meta['year']=meta['release_date'].dt.year

# %%
meta['year'].value_counts().sort_index()
# Out:
# 1874.0       1
# 1878.0       1
# 1883.0       1
# 1887.0       1
# 1888.0       2
#           ...
# 2015.0    1905
# 2016.0    1604
# 2017.0     532
# 2018.0       5
# 2020.0       1
# Name: year, Length: 135, dtype: int64

# %%
new_meta = meta.loc[meta.year == 2017,['genres','id','title','year']]

# %%
new_meta
# Out:
#                                                   genres      id  \
# 26560  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...  166426
# 26561  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...  141052
# 26565  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...  284053
# 26566  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...  283995
# 30536  [{'id': 14, 'name': 'Fantasy'}, {'id': 28, 'na...  245842
# ...                                                  ...     ...
# 45398  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...  468707
# 45417  [{'id': 80, 'name': 'Crime'}, {'id': 35, 'name...  461297
# 45437  [{'id': 10751, 'name': 'Family'}, {'id': 16, '...  455661
# 45453  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...  404604
# 45465                                                 []  461257
#
#                                                   title    year
# 26560  Pirates of the Caribbean: Dead Men Tell No Tales  2017.0
# 26561                                    Justice League  2017.0
# 26565                                    Thor: Ragnarok  2017.0
# 26566                    Guardians of the Galaxy Vol. 2  2017.0
# 30536                               The King's Daughter  2017.0
# ...                                                 ...     ...
# 45398                  Thick Lashes of Lauri Mäntyvaara  2017.0
# 45417                       Cop and a Half: New Recruit  2017.0
# 45437                                    In a Heartbeat  2017.0
# 45453                                               Mom  2017.0
# 45465                                          Queerama  2017.0
#
# [532 rows x 4 columns]

# %%
new_meta = meta.loc[meta.year == 2017,['genres','id','title','year']]

# %%
data = pd.concat([new_meta,credits],axis=1,join="inner")

# %%
pd.set_option('display.max_colwidth', 75)
data
# Out:
#                                                                            genres  \
# 26560  [{'id': 12, 'name': 'Adventure'}, {'id': 28, 'name': 'Action'}, {'id': ...
# 26561  [{'id': 28, 'name': 'Action'}, {'id': 12, 'name': 'Adventure'}, {'id': ...
# 26565  [{'id': 28, 'name': 'Action'}, {'id': 12, 'name': 'Adventure'}, {'id': ...
# 26566  [{'id': 28, 'name': 'Action'}, {'id': 12, 'name': 'Adventure'}, {'id': ...
# 30536  [{'id': 14, 'name': 'Fantasy'}, {'id': 28, 'name': 'Action'}, {'id': 12...
# ...                                                                           ...
# 45398            [{'id': 10749, 'name': 'Romance'}, {'id': 35, 'name': 'Comedy'}]
# 45417  [{'id': 80, 'name': 'Crime'}, {'id': 35, 'name': 'Comedy'}, {'id': 28, ...
# 45437  [{'id': 10751, 'name': 'Family'}, {'id': 16, 'name': 'Animation'}, {'id...
# 45453  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name': 'Drama'}, {'id': 53, '...
# 45465                                                                          []
#
#            id                                             title    year  \
# 26560  166426  Pirates of the Caribbean: Dead Men Tell No Tales  2017.0
# 26561  141052                                    Justice League  2017.0
# 26565  284053                                    Thor: Ragnarok  2017.0
# 26566  283995                    Guardians of the Galaxy Vol. 2  2017.0
# 30536  245842                               The King's Daughter  2017.0
# ...       ...                                               ...     ...
# 45398  468707                  Thick Lashes of Lauri Mäntyvaara  2017.0
# 45417  461297                       Cop and a Half: New Recruit  2017.0
# 45437  455661                                    In a Heartbeat  2017.0
# 45453  404604                                               Mom  2017.0
# 45465  461257                                          Queerama  2017.0
#
#                                                                              cast  \
# 26560  [{'cast_id': 2, 'character': 'Mario Colella', 'credit_id': '52fe48c7c3a...
# 26561  [{'cast_id': 5, 'character': "Scarface' Manzari", 'credit_id': '52fe470...
# 26565  [{'cast_id': 2, 'character': 'Hache', 'credit_id': '52fe4ac1c3a36847f81...
# 26566  [{'cast_id': 2, 'character': 'Max Rockatansky', 'credit_id': '52fe4933c...
# 30536  [{'cast_id': 19, 'character': 'Woo-shik', 'credit_id': '53de573f0e0a265...
# ...                                                                           ...
# 45398                                                                          []
# 45417  [{'cast_id': 1001, 'character': 'Tolik', 'credit_id': '52fe49ea9251416c...
# 45437  [{'cast_id': 1, 'character': 'Joanna', 'credit_id': '5977c41fc3a3682cfd...
# 45453  [{'cast_id': 2, 'character': '', 'credit_id': '5497407ac3a36831b80045cb...
# 45465  [{'cast_id': 5, 'character': '', 'credit_id': '52fe475bc3a368484e0c2a91...
#
#                                                                              crew  \
# 26560  [{'credit_id': '5745ddb792514129a0002fcc', 'department': 'Editing', 'ge...
# 26561  [{'credit_id': '52fe4705c3a368484e0b0e7d', 'department': 'Writing', 'ge...
# 26565  [{'credit_id': '52fe4ac1c3a36847f81dffa1', 'department': 'Directing', '...
# 26566  [{'credit_id': '53d451210e0a262841002dd1', 'department': 'Writing', 'ge...
# 30536  [{'credit_id': '52fe478bc3a36847f813b5b5', 'department': 'Production', ...
# ...                                                                           ...
# 45398  [{'credit_id': '52fe4cbf9251416c751245d1', 'department': 'Directing', '...
# 45417  [{'credit_id': '52fe49ea9251416c750d781f', 'department': 'Directing', '...
# 45437  [{'credit_id': '562e344bc3a3681b5c00ab29', 'department': 'Directing', '...
# 45453  [{'credit_id': '52fe478dc3a36847f813bd5f', 'department': 'Directing', '...
# 45465  [{'credit_id': '5330178a9251413a720055e3', 'department': 'Writing', 'ge...
#
#            id
# 26560   74379
# 26561   65320
# 26565  109689
# 26566   76341
# 30536   49214
# ...       ...
# 45398  184402
# 45417   97672
# 45437  365432
# 45453   49279
# 45465   67179
#
# [532 rows x 7 columns]

# %%
import ast
data['genres']=data['genres'].map(lambda x:ast.literal_eval(x))
data['cast'] = data['cast'].map(lambda x: ast.literal_eval(x))
data['crew'] = data['crew'].map(lambda x: ast.literal_eval(x))

# %%
def make_genresList(x):
    gen = []
    st = " "
    for i in x:
        if i.get('name') == 'Science Fiction':
            scifi = 'Sci-Fi'
            gen.append(scifi)
        else:
            gen.append(i.get('name'))
    if gen == []:
        return np.NaN
    else:
        return (st.join(gen))

# %%
data['genres_list']=data['genres'].map(lambda x: make_genresList(x))

# %%
data['genres_list']
# Out:
# 26560    Adventure Action Fantasy Comedy
# 26561    Action Adventure Fantasy Sci-Fi
# 26565    Action Adventure Fantasy Sci-Fi
# 26566     Action Adventure Comedy Sci-Fi
# 30536           Fantasy Action Adventure
#                       ...
# 45398                     Romance Comedy
# 45417         Crime Comedy Action Family
# 45437    Family Animation Romance Comedy
# 45453               Crime Drama Thriller
# 45465                                NaN
# Name: genres_list, Length: 532, dtype: object

# %%
def get_actor1(x):
    casts=[]
    for i in x:
        casts.append(i.get('name'))
    if casts ==[] or len(casts)<=1:
        return np.NaN
    else:
        return (casts[0])

# %%
data['actor_1_name'] = data['cast'].map(lambda x: get_actor1(x))

# %%
def get_actor2(x):
    casts = []
    for i in x:
        casts.append(i.get('name'))
    if casts == [] or len(casts)<=1:
        return np.NaN
    else:
        return (casts[1])

# %%
data['actor_2_name'] = data['cast'].map(lambda x: get_actor2(x))

# %%
data['actor_2_name']
# Out:
# 26560        James Mason
# 26561          Al Cliver
# 26565         Clara Lago
# 26566    Charlize Theron
# 30536          Han Ga-in
#               ...
# 45398                NaN
# 45417     Yuriy Kutsenko
# 45437      Mark Matechuk
# 45453                NaN
# 45465      Renato Cestiè
# Name: actor_2_name, Length: 532, dtype: object

# %%
def get_actor3(x):
    casts = []
    for i in x:
        casts.append(i.get('name'))
    if casts == [] or len(casts)<=2:
        return np.NaN
    else:
        return (casts[2])

# %%
data['actor_3_name'] = data['cast'].map(lambda x: get_actor3(x))

# %%
data['actor_3_name']
# Out:
# 26560        Marino Masé
# 26561         Harry Baer
# 26565     María Valverde
# 26566     Nicholas Hoult
# 30536       Won-kwon Kim
#               ...
# 45398                NaN
# 45417    Alexey Vorobyov
# 45437     Krista Madison
# 45453                NaN
# 45465       Vito Cipolla
# Name: actor_3_name, Length: 532, dtype: object

# %%
def get_directors(x):
    dt = []
    st = " "
    for i in x:
        if i.get('job') == 'Director':
            dt.append(i.get('name'))
    if dt == []:
        return np.NaN
    else:
        return (st.join(dt))

# %%
data['director_name'] = data['crew'].map(lambda x: get_directors(x))

# %%
data['director_name']
# Out:
# 26560                   Fernando Di Leo
# 26561                   Fernando Di Leo
# 26565          Fernando González Molina
# 26566                     George Miller
# 30536                            Yoo Ha
#                       ...
# 45398                   Walter Ruttmann
# 45417                      Egor Baranov
# 45437                      John Ainslie
# 45453                    Georges Méliès
# 45465    Paolo Taviani Vittorio Taviani
# Name: director_name, Length: 532, dtype: object

# %%
movie = data.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres_list','title']]

# %%
movie
# Out:
#                         director_name      actor_1_name     actor_2_name  \
# 26560                 Fernando Di Leo       Luc Merenda      James Mason
# 26561                 Fernando Di Leo      Jack Palance        Al Cliver
# 26565        Fernando González Molina       Mario Casas       Clara Lago
# 26566                   George Miller         Tom Hardy  Charlize Theron
# 30536                          Yoo Ha      Lee Jung-Jin        Han Ga-in
# ...                               ...               ...              ...
# 45398                 Walter Ruttmann               NaN              NaN
# 45417                    Egor Baranov  Evgeniy Stychkin   Yuriy Kutsenko
# 45437                    John Ainslie       Tianna Nori    Mark Matechuk
# 45453                  Georges Méliès               NaN              NaN
# 45465  Paolo Taviani Vittorio Taviani      Giulio Brogi    Renato Cestiè
#
#           actor_3_name                      genres_list  \
# 26560      Marino Masé  Adventure Action Fantasy Comedy
# 26561       Harry Baer  Action Adventure Fantasy Sci-Fi
# 26565   María Valverde  Action Adventure Fantasy Sci-Fi
# 26566   Nicholas Hoult   Action Adventure Comedy Sci-Fi
# 30536     Won-kwon Kim         Fantasy Action Adventure
# ...                ...                              ...
# 45398              NaN                   Romance Comedy
# 45417  Alexey Vorobyov       Crime Comedy Action Family
# 45437   Krista Madison  Family Animation Romance Comedy
# 45453              NaN             Crime Drama Thriller
# 45465     Vito Cipolla                              NaN
#
#                                                   title
# 26560  Pirates of the Caribbean: Dead Men Tell No Tales
# 26561                                    Justice League
# 26565                                    Thor: Ragnarok
# 26566                    Guardians of the Galaxy Vol. 2
# 30536                               The King's Daughter
# ...                                                 ...
# 45398                  Thick Lashes of Lauri Mäntyvaara
# 45417                       Cop and a Half: New Recruit
# 45437                                    In a Heartbeat
# 45453                                               Mom
# 45465                                          Queerama
#
# [532 rows x 6 columns]

# %%
movie.isna().sum()
# Out:
# director_name    19
# actor_1_name     76
# actor_2_name     76
# actor_3_name     94
# genres_list       8
# title             0
# dtype: int64

# %%
movie = movie.dropna(how='any')

# %%
movie.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres_list      0
# title            0
# dtype: int64

# %%
movie = movie.rename(columns={'genres_list':'genres'})
movie = movie.rename(columns={'title':'movie_title'})

# %%
movie['movie_title'] = movie['movie_title'].str.lower()

# %%
movie['comb'] = movie['actor_1_name'] + ' ' + movie['actor_2_name'] + ' '+ movie['actor_3_name'] + ' '+ movie['director_name'] +' ' + movie['genres']

# %%
movie
# Out:
#                   director_name      actor_1_name       actor_2_name  \
# 26560           Fernando Di Leo       Luc Merenda        James Mason
# 26561           Fernando Di Leo      Jack Palance          Al Cliver
# 26565  Fernando González Molina       Mario Casas         Clara Lago
# 26566             George Miller         Tom Hardy    Charlize Theron
# 30536                    Yoo Ha      Lee Jung-Jin          Han Ga-in
# ...                         ...               ...                ...
# 45375                Cliff Owen    Eric Morecambe         Ernie Wise
# 45380            Fernando Salem    Verónica Gerez       Pilar Gamboa
# 45391   Svyatoslav Podgayevskiy     Mariya Fomina  Dmitri Yendaltsev
# 45417              Egor Baranov  Evgeniy Stychkin     Yuriy Kutsenko
# 45437              John Ainslie       Tianna Nori      Mark Matechuk
#
#              actor_3_name                           genres  \
# 26560         Marino Masé  Adventure Action Fantasy Comedy
# 26561          Harry Baer  Action Adventure Fantasy Sci-Fi
# 26565      María Valverde  Action Adventure Fantasy Sci-Fi
# 26566      Nicholas Hoult   Action Adventure Comedy Sci-Fi
# 30536        Won-kwon Kim         Fantasy Action Adventure
# ...                   ...                              ...
# 45375       Suzanne Lloyd     Fantasy Comedy Romance Drama
# 45380  Rafael Spregelburd                   Romance Comedy
# 45391       Boris Polunin                          Romance
# 45417     Alexey Vorobyov       Crime Comedy Action Family
# 45437      Krista Madison  Family Animation Romance Comedy
#
#                                             movie_title  \
# 26560  pirates of the caribbean: dead men tell no tales
# 26561                                    justice league
# 26565                                    thor: ragnarok
# 26566                    guardians of the galaxy vol. 2
# 30536                               the king's daughter
# ...                                                 ...
# 45375                                         phillauri
# 45380                      the incredible jessica james
# 45391                                 can't buy my love
# 45417                       cop and a half: new recruit
# 45437                                    in a heartbeat
#
#                                                                              comb
# 26560  Luc Merenda James Mason Marino Masé Fernando Di Leo Adventure Action Fa...
# 26561  Jack Palance Al Cliver Harry Baer Fernando Di Leo Action Adventure Fant...
# 26565  Mario Casas Clara Lago María Valverde Fernando González Molina Action A...
# 26566  Tom Hardy Charlize Theron Nicholas Hoult George Miller Action Adventure...
# 30536         Lee Jung-Jin Han Ga-in Won-kwon Kim Yoo Ha Fantasy Action Adventure
# ...                                                                           ...
# 45375  Eric Morecambe Ernie Wise Suzanne Lloyd Cliff Owen Fantasy Comedy Roman...
# 45380  Verónica Gerez Pilar Gamboa Rafael Spregelburd Fernando Salem Romance C...
# 45391  Mariya Fomina Dmitri Yendaltsev Boris Polunin Svyatoslav Podgayevskiy R...
# 45417  Evgeniy Stychkin Yuriy Kutsenko Alexey Vorobyov Egor Baranov Crime Come...
# 45437  Tianna Nori Mark Matechuk Krista Madison John Ainslie Family Animation ...
#
# [428 rows x 7 columns]

# %%
data_1 = pd.read_csv('data.csv')

# %%
data_1
# Out:
#           director_name     actor_1_name      actor_2_name  \
# 0         James Cameron      CCH Pounder  Joel David Moore
# 1        Gore Verbinski      Johnny Depp     Orlando Bloom
# 2            Sam Mendes  Christoph Waltz      Rory Kinnear
# 3     Christopher Nolan        Tom Hardy    Christian Bale
# 4           Doug Walker      Doug Walker        Rob Walker
# ...                 ...              ...               ...
# 5038        Scott Smith      Eric Mabius     Daphne Zuniga
# 5039            unknown      Natalie Zea     Valorie Curry
# 5040   Benjamin Roberds      Eva Boehnke     Maxwell Moody
# 5041        Daniel Hsia        Alan Ruck     Daniel Henney
# 5042           Jon Gunn      John August  Brian Herzlinger
#
#               actor_3_name                        genres  \
# 0                Wes Studi  ActionAdventureFantasySci-Fi
# 1           Jack Davenport        ActionAdventureFantasy
# 2         Stephanie Sigman       ActionAdventureThriller
# 3     Joseph Gordon-Levitt                ActionThriller
# 4                  unknown                   Documentary
# ...                    ...                           ...
# 5038          Crystal Lowe                   ComedyDrama
# 5039         Sam Underwood     CrimeDramaMysteryThriller
# 5040        David Chandler           DramaHorrorThriller
# 5041           Eliza Coupe            ComedyDramaRomance
# 5042              Jon Gunn                   Documentary
#
#                                                  movie_title
# 0                                                     avatar
# 1                   pirates of the caribbean: at world's end
# 2                                                    spectre
# 3                                      the dark knight rises
# 4     star wars: episode vii - the force awakens
# ...                                                      ...
# 5038                                 signed sealed delivered
# 5039                               the following
# 5040                                    a plague so pleasant
# 5041                                        shanghai calling
# 5042                                       my date with drew
#
# [5043 rows x 6 columns]

# %%
data_1['comb'] = data_1['actor_1_name'] + ' ' + data_1['actor_2_name'] + ' '+ data_1['actor_3_name'] + ' '+ data_1['director_name'] +' ' + data_1['genres']

# %%
data_1
# Out:
#           director_name     actor_1_name      actor_2_name  \
# 0         James Cameron      CCH Pounder  Joel David Moore
# 1        Gore Verbinski      Johnny Depp     Orlando Bloom
# 2            Sam Mendes  Christoph Waltz      Rory Kinnear
# 3     Christopher Nolan        Tom Hardy    Christian Bale
# 4           Doug Walker      Doug Walker        Rob Walker
# ...                 ...              ...               ...
# 5038        Scott Smith      Eric Mabius     Daphne Zuniga
# 5039            unknown      Natalie Zea     Valorie Curry
# 5040   Benjamin Roberds      Eva Boehnke     Maxwell Moody
# 5041        Daniel Hsia        Alan Ruck     Daniel Henney
# 5042           Jon Gunn      John August  Brian Herzlinger
#
#               actor_3_name                        genres  \
# 0                Wes Studi  ActionAdventureFantasySci-Fi
# 1           Jack Davenport        ActionAdventureFantasy
# 2         Stephanie Sigman       ActionAdventureThriller
# 3     Joseph Gordon-Levitt                ActionThriller
# 4                  unknown                   Documentary
# ...                    ...                           ...
# 5038          Crystal Lowe                   ComedyDrama
# 5039         Sam Underwood     CrimeDramaMysteryThriller
# 5040        David Chandler           DramaHorrorThriller
# 5041           Eliza Coupe            ComedyDramaRomance
# 5042              Jon Gunn                   Documentary
#
#                                                  movie_title  \
# 0                                                     avatar
# 1                   pirates of the caribbean: at world's end
# 2                                                    spectre
# 3                                      the dark knight rises
# 4     star wars: episode vii - the force awakens
# ...                                                      ...
# 5038                                 signed sealed delivered
# 5039                               the following
# 5040                                    a plague so pleasant
# 5041                                        shanghai calling
# 5042                                       my date with drew
#
#                                                                             comb
# 0     CCH Pounder Joel David Moore Wes Studi James Cameron ActionAdventureFan...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore Verbinski ActionAdventure...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman Sam Mendes ActionAdventur...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt Christopher Nolan ActionT...
# 4                         Doug Walker Rob Walker unknown Doug Walker Documentary
# ...                                                                          ...
# 5038              Eric Mabius Daphne Zuniga Crystal Lowe Scott Smith ComedyDrama
# 5039   Natalie Zea Valorie Curry Sam Underwood unknown CrimeDramaMysteryThriller
# 5040  Eva Boehnke Maxwell Moody David Chandler Benjamin Roberds DramaHorrorTh...
# 5041          Alan Ruck Daniel Henney Eliza Coupe Daniel Hsia ComedyDramaRomance
# 5042                  John August Brian Herzlinger Jon Gunn Jon Gunn Documentary
#
# [5043 rows x 7 columns]

# %%
 data_2= data_1.append(movie)

# %%
data_2
# Out:
#                  director_name      actor_1_name       actor_2_name  \
# 0                James Cameron       CCH Pounder   Joel David Moore
# 1               Gore Verbinski       Johnny Depp      Orlando Bloom
# 2                   Sam Mendes   Christoph Waltz       Rory Kinnear
# 3            Christopher Nolan         Tom Hardy     Christian Bale
# 4                  Doug Walker       Doug Walker         Rob Walker
# ...                        ...               ...                ...
# 45375               Cliff Owen    Eric Morecambe         Ernie Wise
# 45380           Fernando Salem    Verónica Gerez       Pilar Gamboa
# 45391  Svyatoslav Podgayevskiy     Mariya Fomina  Dmitri Yendaltsev
# 45417             Egor Baranov  Evgeniy Stychkin     Yuriy Kutsenko
# 45437             John Ainslie       Tianna Nori      Mark Matechuk
#
#                actor_3_name                           genres  \
# 0                 Wes Studi     ActionAdventureFantasySci-Fi
# 1            Jack Davenport           ActionAdventureFantasy
# 2          Stephanie Sigman          ActionAdventureThriller
# 3      Joseph Gordon-Levitt                   ActionThriller
# 4                   unknown                      Documentary
# ...                     ...                              ...
# 45375         Suzanne Lloyd     Fantasy Comedy Romance Drama
# 45380    Rafael Spregelburd                   Romance Comedy
# 45391         Boris Polunin                          Romance
# 45417       Alexey Vorobyov       Crime Comedy Action Family
# 45437        Krista Madison  Family Animation Romance Comedy
#
#                                                   movie_title  \
# 0                                                      avatar
# 1                    pirates of the caribbean: at world's end
# 2                                                     spectre
# 3                                       the dark knight rises
# 4      star wars: episode vii - the force awakens
# ...                                                       ...
# 45375                                               phillauri
# 45380                            the incredible jessica james
# 45391                                       can't buy my love
# 45417                             cop and a half: new recruit
# 45437                                          in a heartbeat
#
#                                                                              comb
# 0      CCH Pounder Joel David Moore Wes Studi James Cameron ActionAdventureFan...
# 1      Johnny Depp Orlando Bloom Jack Davenport Gore Verbinski ActionAdventure...
# 2      Christoph Waltz Rory Kinnear Stephanie Sigman Sam Mendes ActionAdventur...
# 3      Tom Hardy Christian Bale Joseph Gordon-Levitt Christopher Nolan ActionT...
# 4                          Doug Walker Rob Walker unknown Doug Walker Documentary
# ...                                                                           ...
# 45375  Eric Morecambe Ernie Wise Suzanne Lloyd Cliff Owen Fantasy Comedy Roman...
# 45380  Verónica Gerez Pilar Gamboa Rafael Spregelburd Fernando Salem Romance C...
# 45391  Mariya Fomina Dmitri Yendaltsev Boris Polunin Svyatoslav Podgayevskiy R...
# 45417  Evgeniy Stychkin Yuriy Kutsenko Alexey Vorobyov Egor Baranov Crime Come...
# 45437  Tianna Nori Mark Matechuk Krista Madison John Ainslie Family Animation ...
#
# [5471 rows x 7 columns]

# %%
data_2.drop_duplicates(subset ="movie_title", keep = 'last', inplace = True)

# %%
data_2
# Out:
#                  director_name      actor_1_name       actor_2_name  \
# 0                James Cameron       CCH Pounder   Joel David Moore
# 1               Gore Verbinski       Johnny Depp      Orlando Bloom
# 2                   Sam Mendes   Christoph Waltz       Rory Kinnear
# 3            Christopher Nolan         Tom Hardy     Christian Bale
# 4                  Doug Walker       Doug Walker         Rob Walker
# ...                        ...               ...                ...
# 45375               Cliff Owen    Eric Morecambe         Ernie Wise
# 45380           Fernando Salem    Verónica Gerez       Pilar Gamboa
# 45391  Svyatoslav Podgayevskiy     Mariya Fomina  Dmitri Yendaltsev
# 45417             Egor Baranov  Evgeniy Stychkin     Yuriy Kutsenko
# 45437             John Ainslie       Tianna Nori      Mark Matechuk
#
#                actor_3_name                           genres  \
# 0                 Wes Studi     ActionAdventureFantasySci-Fi
# 1            Jack Davenport           ActionAdventureFantasy
# 2          Stephanie Sigman          ActionAdventureThriller
# 3      Joseph Gordon-Levitt                   ActionThriller
# 4                   unknown                      Documentary
# ...                     ...                              ...
# 45375         Suzanne Lloyd     Fantasy Comedy Romance Drama
# 45380    Rafael Spregelburd                   Romance Comedy
# 45391         Boris Polunin                          Romance
# 45417       Alexey Vorobyov       Crime Comedy Action Family
# 45437        Krista Madison  Family Animation Romance Comedy
#
#                                                   movie_title  \
# 0                                                      avatar
# 1                    pirates of the caribbean: at world's end
# 2                                                     spectre
# 3                                       the dark knight rises
# 4      star wars: episode vii - the force awakens
# ...                                                       ...
# 45375                                               phillauri
# 45380                            the incredible jessica james
# 45391                                       can't buy my love
# 45417                             cop and a half: new recruit
# 45437                                          in a heartbeat
#
#                                                                              comb
# 0      CCH Pounder Joel David Moore Wes Studi James Cameron ActionAdventureFan...
# 1      Johnny Depp Orlando Bloom Jack Davenport Gore Verbinski ActionAdventure...
# 2      Christoph Waltz Rory Kinnear Stephanie Sigman Sam Mendes ActionAdventur...
# 3      Tom Hardy Christian Bale Joseph Gordon-Levitt Christopher Nolan ActionT...
# 4                          Doug Walker Rob Walker unknown Doug Walker Documentary
# ...                                                                           ...
# 45375  Eric Morecambe Ernie Wise Suzanne Lloyd Cliff Owen Fantasy Comedy Roman...
# 45380  Verónica Gerez Pilar Gamboa Rafael Spregelburd Fernando Salem Romance C...
# 45391  Mariya Fomina Dmitri Yendaltsev Boris Polunin Svyatoslav Podgayevskiy R...
# 45417  Evgeniy Stychkin Yuriy Kutsenko Alexey Vorobyov Egor Baranov Crime Come...
# 45437  Tianna Nori Mark Matechuk Krista Madison John Ainslie Family Animation ...
#
# [5336 rows x 7 columns]

# %%
data_2.to_csv('new_data.csv',index=False)
